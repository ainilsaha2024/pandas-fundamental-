# %%
import pandas as pd 
df =pd.read_csv("pandas_dataset_csv.csv")

# %%
#Shape of the dataframe 
df.shape
# Out:
# (307, 16)

# %%
row, col = df.shape

# %%
print(row)
# Out:
# 307

# %%
print(col)
# Out:
# 16

# %%
#Top nth rows 
df.head(10)
# Out:
#    id              name               nationality                 city  \
# 0   0         Kiana Lor                     China               Suzhou
# 1   1    Joshua Lonaker  United States of America        Santa Clarita
# 2   2     Dakota Blanco  United States of America              Oakland
# 3   3   Natasha Yarusso  United States of America        Castro Valley
# 4   4    Brooke Cazares                    Brazil  São José dos Campos
# 5   5  Rochelle Johnson  United States of America         Indianapolis
# 6   6        Joey Abreu                     China             Shenyang
# 7   7    Preston Suarez                    Brazil            São Paulo
# 8   8          Lee Dong               Philippines               Manila
# 9   9     Maa'iz al-Dia                    Turkey             Istanbul
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# ...

# %%
# last nth rows 
df.tail(8)
# Out:
#       id                  name               nationality         city  \
# 299  299  Christopher Inhulsen  United States of America   Fort Worth
# 300  300       Tessa Rawanduzy  United States of America        Derby
# 301  301      Vanessa Gonzalez                 Nicaragua         León
# 302  302           Austin Haas  United States of America     Columbus
# 303  303       Madison Fithian  United States of America  Los Angeles
# 304  304     Zachary Mulvahill  United States of America  Los Angeles
# 305  305      Eliana Michelsen  United States of America      Oakland
# 306  306       Dane Whittemore                    Canada      Toronto
#
#      latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 299     32.73     -97.32      M           NaN   23            3.1         3.3
# 300     37.55     -97.27      F           NaN   21            3.3         3.3
# 301     12.44     -86.88      F           NaN   24            3.3         3.7
# ...

# %%
#Range of entries 
df[5:10]
# Out:
#    id              name               nationality          city  latitude  \
# 5   5  Rochelle Johnson  United States of America  Indianapolis     39.77
# 6   6        Joey Abreu                     China      Shenyang     41.79
# 7   7    Preston Suarez                    Brazil     São Paulo    -23.47
# 8   8          Lee Dong               Philippines        Manila     14.60
# 9   9     Maa'iz al-Dia                    Turkey      Istanbul     41.02
#
#    longitude gender  ethnic.group  age  english.grade  math.grade  \
# 5     -86.16      F           NaN   21            3.4         3.1
# 6     123.43      M           NaN   22            3.7         3.9
# 7     -46.67      M           NaN   22            3.8         3.7
# 8     120.98      F           NaN   24            3.9         3.6
# 9      28.96      M           NaN   22            2.4         2.8
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# ...

# %%
# Accessing nth columns
df.name
# Out:
# 0              Kiana Lor
# 1         Joshua Lonaker
# 2          Dakota Blanco
# 3        Natasha Yarusso
# 4         Brooke Cazares
#              ...
# 302          Austin Haas
# 303      Madison Fithian
# 304    Zachary Mulvahill
# 305     Eliana Michelsen
# 306      Dane Whittemore
# Name: name, Length: 307, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender',
#        'ethnic.group', 'age', 'english.grade', 'math.grade', 'sciences.grade',
#        'language.grade', 'portfolio.rating', 'coverletter.rating',
#        'refletter.rating'],
#       dtype='object')

# %%
df[["name","city"]].head(5)
# Out:
#               name                 city
# 0        Kiana Lor               Suzhou
# 1   Joshua Lonaker        Santa Clarita
# 2    Dakota Blanco              Oakland
# 3  Natasha Yarusso        Castro Valley
# 4   Brooke Cazares  São José dos Campos

# %%
# Type of columns 
type(df["name"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Basic Statistical Function

# %%
df.index
# Out:
# RangeIndex(start=0, stop=307, step=1)

# %%
len(df)
# Out:
# 307

# %%
df.columns
# Out:
# Index(['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender',
#        'ethnic.group', 'age', 'english.grade', 'math.grade', 'sciences.grade',
#        'language.grade', 'portfolio.rating', 'coverletter.rating',
#        'refletter.rating'],
#       dtype='object')

# %%
#max value 
df["age"].max()
# Out:
# np.int64(26)

# %%
#mini
df["age"].min()
# Out:
# np.int64(19)

# %%
#mean
df["age"].mean()
# Out:
# np.float64(21.964169381107492)

# %%
#std
df["age"].std()
# Out:
# np.float64(1.2480126203801174)

# %%
#mode 
df["age"].mode()
# Out:
# 0    22
# Name: age, dtype: int64

# %%
#clount
df["age"].count()
# Out:
# np.int64(307)

# %%
#clount value
df["age"].value_counts()
# Out:
# age
# 22    93
# 21    71
# 23    71
# 20    35
# 24    29
# 19     4
# 25     3
# 26     1
# Name: count, dtype: int64

# %%
# 25 % 
df["age"].quantile(0.25)
# Out:
# np.float64(21.0)

# %%
#50%
df["age"].quantile(0.50)
# Out:
# np.float64(22.0)

# %%
#100%
df["age"].quantile(1)
# Out:
# np.float64(26.0)

# %%
df.describe()
# Out:
#                id    latitude   longitude  ethnic.group         age  \
# count  307.000000  307.000000  307.000000           0.0  307.000000
# mean   153.000000   32.863388  -64.539121           NaN   21.964169
# std     88.767487   13.498582   81.249146           NaN    1.248013
# min      0.000000  -33.450000 -123.130000           NaN   19.000000
# 25%     76.500000   32.720000 -118.240000           NaN   21.000000
# 50%    153.000000   34.390000  -99.140000           NaN   22.000000
# 75%    229.500000   38.960000  -73.855000           NaN   23.000000
# max    306.000000   59.890000  139.750000           NaN   26.000000
#
#        english.grade  math.grade  sciences.grade  language.grade  \
# count     307.000000  307.000000      307.000000      307.000000
# mean        3.369707    3.414332        3.446580        4.396417
# std         0.538724    0.476839        0.509081        0.996474
# min         1.500000    2.100000        1.400000        1.000000
# ...

# %% [markdown]
# # Value Sorting

# %%
df.head(5)
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# ...

# %%
df["age"].sort_values()
# Out:
# 173    19
# 140    19
# 229    19
# 131    19
# 60     20
#        ..
# 8      24
# 200    25
# 133    25
# 80     25
# 83     26
# Name: age, Length: 307, dtype: int64

# %%
df["age"].sort_values(ascending=False)
# Out:
# 83     26
# 133    25
# 200    25
# 80     25
# 256    24
#        ..
# 98     20
# 140    19
# 173    19
# 131    19
# 229    19
# Name: age, Length: 307, dtype: int64

# %%
df.nlargest(10,"age")
# Out:
#       id                 name               nationality         city  \
# 83    83           Luke Davey  United States of America  Los Angeles
# 80    80         Sean Tegtman  United States of America    Kettering
# 133  133         Andrew Kirin  United States of America       Odessa
# 200  200         Kitty Nguyen                     Japan        Tokyo
# 8      8             Lee Dong               Philippines       Manila
# 18    18           David Pulc                    Canada      Toronto
# 38    38      Joshua Galloway  United States of America     New York
# 44    44      Tawnie Glaisher  United States of America      Fremont
# 69    69  Allison Brink-Lomme  United States of America     Portland
# 97    97        William Pablo                     Japan    Kashiwara
#
#      latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 83      34.05    -118.24      M           NaN   26            3.8         3.4
# ...

# %%
df.nsmallest(10,"age")
# Out:
#       id               name               nationality           city  \
# 131  131       Shauna Sneed  United States of America     Burlingame
# 140  140       Faviola Soto                    Mexico       Cortazar
# 173  173         Sean Bruso            United Kingdom         London
# 229  229   Katherine Beatty  United States of America    Los Angeles
# 3      3    Natasha Yarusso  United States of America  Castro Valley
# 12    12  Alexander Sherman  United States of America          Omaha
# 21    21        David Weber                     China         Peking
# 46    46         Alan Trinh                     Japan          Tokyo
# 58    58  Cameron Steinberg  United States of America    Los Angeles
# 60    60      Katelyn Sharp  United States of America    Los Angeles
#
#      latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 131     37.58    -122.36      F           NaN   19            2.7         3.7
# ...

# %% [markdown]
# # Conditional Statements

# %%
df.head()
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# ...

# %%
df["longitude"].max()
# Out:
# np.float64(139.75)

# %%
df[df["longitude"] > 100]
# Out:
#       id              name          nationality       city  latitude  \
# 0      0         Kiana Lor                China     Suzhou     31.31
# 6      6        Joey Abreu                China   Shenyang     41.79
# 8      8          Lee Dong          Philippines     Manila     14.60
# 15    15     Brittany Sath                Japan      Tokyo     35.69
# 20    20        Rojesh Her                Japan      Tokyo     35.69
# 21    21       David Weber                China     Peking     39.93
# 24    24       Sila Nguyen                China       Hebi     35.90
# 37    37     Katrina Saito                Japan      Tokyo     35.69
# 43    43   Kenny Fukushima                Japan      Tokyo     35.69
# 46    46        Alan Trinh                Japan      Tokyo     35.69
# 61    61      Colin Lemont                China   Shanghai     31.05
# 68    68   Gabrielle Smith  Korea (Republic of)      Seoul     37.60
# 76    76  Sourinthone Tran                China      Wuhan     30.58
# ...

# %%
#subseting rows
df[df["nationality"] =="China"]
# Out:
#       id              name nationality       city  latitude  longitude gender  \
# 0      0         Kiana Lor       China     Suzhou     31.31     120.62      F
# 6      6        Joey Abreu       China   Shenyang     41.79     123.43      M
# 21    21       David Weber       China     Peking     39.93     116.39      M
# 24    24       Sila Nguyen       China       Hebi     35.90     114.19      M
# 61    61      Colin Lemont       China   Shanghai     31.05     121.40      M
# 76    76  Sourinthone Tran       China      Wuhan     30.58     114.27      M
# 162  162    Rebecca Ah Fat       China   Tangshan     37.33     114.70      F
# 176  176          Surya Ky       China   Tangshan     37.33     114.70      M
# 189  189          Emma Kim       China   Hengshui     37.73     115.70      F
# 194  194  Chue Fue Richter       China    Qiqihar     47.34     123.97      M
# 214  214    Christian Chow       China     Handan     36.57     114.53      M
# ...

# %%
a=df[(df["nationality"] =="China") | (df["nationality"] =="Japan")]

# %%
print(len(a))
# Out:
# 26

# %%
a
# Out:
#       id              name nationality       city  latitude  longitude gender  \
# 0      0         Kiana Lor       China     Suzhou     31.31     120.62      F
# 6      6        Joey Abreu       China   Shenyang     41.79     123.43      M
# 15    15     Brittany Sath       Japan      Tokyo     35.69     139.75      F
# 20    20        Rojesh Her       Japan      Tokyo     35.69     139.75      M
# 21    21       David Weber       China     Peking     39.93     116.39      M
# 24    24       Sila Nguyen       China       Hebi     35.90     114.19      M
# 37    37     Katrina Saito       Japan      Tokyo     35.69     139.75      F
# 43    43   Kenny Fukushima       Japan      Tokyo     35.69     139.75      M
# 46    46        Alan Trinh       Japan      Tokyo     35.69     139.75      M
# 61    61      Colin Lemont       China   Shanghai     31.05     121.40      M
# 76    76  Sourinthone Tran       China      Wuhan     30.58     114.27      M
# ...

# %%
#subseting using isin ( )
df[df["nationality"].isin(["China","Japan"])]
# Out:
#       id              name nationality       city  latitude  longitude gender  \
# 0      0         Kiana Lor       China     Suzhou     31.31     120.62      F
# 6      6        Joey Abreu       China   Shenyang     41.79     123.43      M
# 15    15     Brittany Sath       Japan      Tokyo     35.69     139.75      F
# 20    20        Rojesh Her       Japan      Tokyo     35.69     139.75      M
# 21    21       David Weber       China     Peking     39.93     116.39      M
# 24    24       Sila Nguyen       China       Hebi     35.90     114.19      M
# 37    37     Katrina Saito       Japan      Tokyo     35.69     139.75      F
# 43    43   Kenny Fukushima       Japan      Tokyo     35.69     139.75      M
# 46    46        Alan Trinh       Japan      Tokyo     35.69     139.75      M
# 61    61      Colin Lemont       China   Shanghai     31.05     121.40      M
# 76    76  Sourinthone Tran       China      Wuhan     30.58     114.27      M
# ...

# %%
x=df[df["nationality"].isin(["China","Japan"])]
print(len(x))
# Out:
# 26
